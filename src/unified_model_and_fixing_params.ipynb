# %%
from pathlib import Path
import pickle
import numpy as np
import matplotlib.pyplot as plt
from marker_analyser.classes import OscillationCollection
from marker_analyser.configuration import FitConfig, ParamConfig
from pydantic import BaseModel, model_validator, ValidationError

from lumicks import pylake
from typing import Self

# %%
# Load the data
dir_data = Path("../experimenting_data")
with open(dir_data / "marina_data_loaded_oscillations.pkl", "rb") as file:
    oscillations: OscillationCollection = pickle.load(file)
    assert type(oscillations) == OscillationCollection

# get only the first 10 oscillations for testing
first_10_oscillation_ids = list(oscillations.oscillations.keys())[:10]
oscillations = OscillationCollection(
    oscillations={osc_id: oscillations.oscillations[osc_id] for osc_id in first_10_oscillation_ids}
)

print(f"Loaded {len(oscillations.oscillations)} oscillations for testing.")
# Out:
# Loaded 10 oscillations for testing.

# %%
fit_config = FitConfig(
    params_config={
        "Lp": ParamConfig(lower_bound=0, upper_bound=None, initial_value=5, global_param=False, fixed=False),
        "Lc": ParamConfig(lower_bound=0, initial_value=1, global_param=False, fixed=False),
    },
    auto_calculate_and_fix_f_offset=True,
    f_offset_auto_detect_distance_range_um=(10, 12),
    model_name="fit",
    segment="both",
)

# fit all globally

oscillations.fit_global_model_to_all(fit_config=fit_config)

# oscillations.plot_all(random_colours=True)

file_results_path = dir_data / "output_global_fit_results.csv"
oscillations.global_fit_save_parameters_to_csv_file(file_path=file_results_path)


# fit all individually
# oscillations.fit_individual_model_to_each(fit_config=fit_config)

# oscillations.save_collection_data_to_csv_file(
#     file_path=dir_data / "output_individual_fit_results.csv",
#     segment="both"
# )
# Out:
# Fitted global model to 10 for segment FitSegment.BOTH. Results:
# Fit
#   - Model: fit_with_fit
#   - Equation:
#       f(d) = argmin[f](norm(fit.Lc * (1 - (1/2)*sqrt(kT/(f*fit.Lp)) + f/fit.St)-d)) + fit.f_offset
#
#   - Data sets:
#     - FitData(Oscillation curve_CuOda_0.5uM_M3_1_oscillation_0, segment FitSegment.BOTH, N=642, Transformations: fit/Lp → fit/Lp_curve_CuOda_0.5uM_M3_1_oscillation_0, fit/Lc → fit/Lc_curve_CuOda_0.5uM_M3_1_oscillation_0, fit/f_offset → fit/f_offset_curve_CuOda_0.5uM_M3_1_oscillation_0)
#     - FitData(Oscillation curve_CuOda_0.5uM_M3_1_oscillation_1, segment FitSegment.BOTH, N=642, Transformations: fit/Lp → fit/Lp_curve_CuOda_0.5uM_M3_1_oscillation_1, fit/Lc → fit/Lc_curve_CuOda_0.5uM_M3_1_oscillation_1, fit/f_offset → fit/f_offset_curve_CuOda_0.5uM_M3_1_oscillation_1)
#     - FitData(Oscillation curve_CuOda_0.5uM_M3_1_oscillation_2, segment FitSegment.BOTH, N=640, Transformations: fit/Lp → fit/Lp_curve_CuOda_0.5uM_M3_1_oscillation_2, fit/Lc → fit/Lc_curve_CuOda_0.5uM_M3_1_oscillation_2, fit/f_offset → fit/f_offset_curve_CuOda_0.5uM_M3_1_oscillation_2)
#     - FitData(Oscillation curve_CuOda_0uM_M3_1_oscillation_0, segment FitSegment.BOTH, N=621, Transformations: fit/Lp → fit/Lp_curve_CuOda_0uM_M3_1_oscillation_0, fit/Lc → fit/Lc_curve_CuOda_0uM_M3_1_oscillation_0, fit/f_offset → fit/f_offset_curve_CuOda_0uM_M3_1_oscillation_0)
#     - FitData(Oscillation curve_CuOda_0uM_M3_1_oscillation_1, segment FitSegment.BOTH, N=621, Transformations: fit/Lp → fit/Lp_curve_CuOda_0uM_M3_1_oscillation_1, fit/Lc → fit/Lc_curve_CuOda_0uM_M3_1_oscillation_1, fit/f_offset → fit/f_offset_curve_CuOda_0uM_M3_1_oscillation_1)
#     - FitData(Oscillation curve_CuOda_0uM_M3_1_oscillation_2, segment FitSegment.BOTH, N=622, Transformations: fit/Lp → fit/Lp_curve_CuOda_0uM_M3_1_oscillation_2, fit/Lc → fit/Lc_curve_CuOda_0uM_M3_1_oscillation_2, fit/f_offset → fit/f_offset_curve_CuOda_0uM_M3_1_oscillation_2)
#     - FitData(Oscillation curve_CuOda_0uM_M3_2_oscillation_0, segment FitSegment.BOTH, N=623, Transformations: fit/Lp → fit/Lp_curve_CuOda_0uM_M3_2_oscillation_0, fit/Lc → fit/Lc_curve_CuOda_0uM_M3_2_oscillation_0, fit/f_offset → fit/f_offset_curve_CuOda_0uM_M3_2_oscillation_0)
#     - FitData(Oscillation curve_CuOda_0uM_M3_2_oscillation_1, segment FitSegment.BOTH, N=624, Transformations: fit/Lp → fit/Lp_curve_CuOda_0uM_M3_2_oscillation_1, fit/Lc → fit/Lc_curve_CuOda_0uM_M3_2_oscillation_1, fit/f_offset → fit/f_offset_curve_CuOda_0uM_M3_2_oscillation_1)
#     - FitData(Oscillation curve_CuOda_0uM_M3_2_oscillation_2, segment FitSegment.BOTH, N=624, Transformations: fit/Lp → fit/Lp_curve_CuOda_0uM_M3_2_oscillation_2, fit/Lc → fit/Lc_curve_CuOda_0uM_M3_2_oscillation_2, fit/f_offset → fit/f_offset_curve_CuOda_0uM_M3_2_oscillation_2)
#     - FitData(Oscillation curve_CuOda_0uM_M3_3_oscillation_0, segment FitSegment.BOTH, N=624, Transformations: fit/Lp → fit/Lp_curve_CuOda_0uM_M3_3_oscillation_0, fit/Lc → fit/Lc_curve_CuOda_0uM_M3_3_oscillation_0, fit/f_offset → fit/f_offset_curve_CuOda_0uM_M3_3_oscillation_0)
#
#   - Fitted parameters:
#     Name                                                    Value  Unit      Fitted      Lower bound    Upper bound
#     -------------------------------------------------  ----------  --------  --------  -------------  -------------
#     fit/Lp_curve_CuOda_0.5uM_M3_1_oscillation_0         51.5393    [nm]      True               0             100
#     fit/Lc_curve_CuOda_0.5uM_M3_1_oscillation_0         16.347     [micron]  True               0             inf
#     fit/St                                             911.327     [pN]      True               1             inf
#     kT                                                   4.11      [pN*nm]   False              3.77            8
#     fit/f_offset_curve_CuOda_0.5uM_M3_1_oscillation_0    0.259325  [pN]      False             -0.1             0.1
#     fit/Lp_curve_CuOda_0.5uM_M3_1_oscillation_1         50.976     [nm]      True               0             100
#     fit/Lc_curve_CuOda_0.5uM_M3_1_oscillation_1         16.3512    [micron]  True               0             inf
#     fit/f_offset_curve_CuOda_0.5uM_M3_1_oscillation_1    0.271894  [pN]      False             -0.1             0.1
#     fit/Lp_curve_CuOda_0.5uM_M3_1_oscillation_2         53.5235    [nm]      True               0             100
#     fit/Lc_curve_CuOda_0.5uM_M3_1_oscillation_2         16.3347    [micron]  True               0             inf
#     fit/f_offset_curve_CuOda_0.5uM_M3_1_oscillation_2    0.277539  [pN]      False             -0.1             0.1
#     fit/Lp_curve_CuOda_0uM_M3_1_oscillation_0           74.5372    [nm]      True               0             100
#     fit/Lc_curve_CuOda_0uM_M3_1_oscillation_0           16.089     [micron]  True               0             inf
#     fit/f_offset_curve_CuOda_0uM_M3_1_oscillation_0      0.221645  [pN]      False             -0.1             0.1
#     fit/Lp_curve_CuOda_0uM_M3_1_oscillation_1           72.9266    [nm]      True               0             100
#     fit/Lc_curve_CuOda_0uM_M3_1_oscillation_1           16.0974    [micron]  True               0             inf
#     fit/f_offset_curve_CuOda_0uM_M3_1_oscillation_1      0.23459   [pN]      False             -0.1             0.1
#     fit/Lp_curve_CuOda_0uM_M3_1_oscillation_2           71.3912    [nm]      True               0             100
#     fit/Lc_curve_CuOda_0uM_M3_1_oscillation_2           16.0997    [micron]  True               0             inf
#     fit/f_offset_curve_CuOda_0uM_M3_1_oscillation_2      0.211925  [pN]      False             -0.1             0.1
#     fit/Lp_curve_CuOda_0uM_M3_2_oscillation_0           81.9502    [nm]      True               0             100
#     fit/Lc_curve_CuOda_0uM_M3_2_oscillation_0           16.0788    [micron]  True               0             inf
#     fit/f_offset_curve_CuOda_0uM_M3_2_oscillation_0      0.201306  [pN]      False             -0.1             0.1
#     fit/Lp_curve_CuOda_0uM_M3_2_oscillation_1           85.6813    [nm]      True               0             100
#     fit/Lc_curve_CuOda_0uM_M3_2_oscillation_1           16.0699    [micron]  True               0             inf
#     fit/f_offset_curve_CuOda_0uM_M3_2_oscillation_1      0.246179  [pN]      False             -0.1             0.1
#     fit/Lp_curve_CuOda_0uM_M3_2_oscillation_2           83.599     [nm]      True               0             100
#     fit/Lc_curve_CuOda_0uM_M3_2_oscillation_2           16.0773    [micron]  True               0             inf
#     fit/f_offset_curve_CuOda_0uM_M3_2_oscillation_2      0.240543  [pN]      False             -0.1             0.1
#     fit/Lp_curve_CuOda_0uM_M3_3_oscillation_0           72.9449    [nm]      True               0             100
#     fit/Lc_curve_CuOda_0uM_M3_3_oscillation_0           16.1046    [micron]  True               0             inf
#     fit/f_offset_curve_CuOda_0uM_M3_3_oscillation_0      0.223849  [pN]      False             -0.1             0.1
